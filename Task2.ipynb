# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Train.csv')
df.head()
# Out:
#    beds  baths  size size_unit  lot_size lot_size_unit  zip_code   price
# 0     3    2.0  1800      sqft      0.20          acre     12345  480000
# 1     4    2.5  1500      sqft      0.22          acre     54321  420000
# 2     2    1.0  1100      sqft      0.12          acre     98765  300000
# 3     4    2.5  1500      sqft      0.22          acre     12345  250000
# 4     5    3.0  2200      sqft      0.35          acre     78912  780000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   beds           10 non-null     int64
#  1   baths          10 non-null     float64
#  2   size           10 non-null     int64
#  3   size_unit      10 non-null     object
#  4   lot_size       10 non-null     float64
#  5   lot_size_unit  10 non-null     object
#  6   zip_code       10 non-null     int64
#  7   price          10 non-null     int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 768.0+ bytes

# %%
for column in df.columns:
    print(df[column].value_counts())
    print("*"*20)
# Out:
# 4    4
# 3    3
# 2    2
# 5    1
# Name: beds, dtype: int64
# ********************
# 2.0    3
# 2.5    3
# 1.5    2
# 1.0    1
# 3.0    1
# Name: baths, dtype: int64
# ********************
# 1500    2
# 1400    2
# 1800    1
# 1100    1
# 2200    1
# 1700    1
# 1200    1
# 2000    1
# Name: size, dtype: int64
# ********************
# sqft    10
# Name: size_unit, dtype: int64
# ********************
# 0.22    2
# 0.15    2
# 0.20    1
# 0.12    1
# 0.35    1
# 0.28    1
# 0.18    1
# 0.32    1
# Name: lot_size, dtype: int64
# ********************
# acre    10
# Name: lot_size_unit, dtype: int64
# ********************
# 12345    3
# 54321    3
# 98765    2
# 78912    2
# Name: zip_code, dtype: int64
# ********************
# 480000    1
# 420000    1
# 300000    1
# 250000    1
# 780000    1
# 550000    1
# 380000    1
# 320000    1
# 270000    1
# 750000    1
# Name: price, dtype: int64
# ********************

# %%
df.isna().sum()
# Out:
# beds             0
# baths            0
# size             0
# size_unit        0
# lot_size         0
# lot_size_unit    0
# zip_code         0
# price            0
# dtype: int64

# %%
df.drop(columns=['lot_size','lot_size_unit'],inplace=True)

# %%
df.describe()
# Out:
#             beds      baths         size      zip_code          price
# count  10.000000  10.000000    10.000000     10.000000      10.000000
# mean    3.400000   2.050000  1580.000000  55535.200000  450000.000000
# std     0.966092   0.598609   345.768066  34044.388909  190729.593346
# min     2.000000   1.000000  1100.000000  12345.000000  250000.000000
# 25%     3.000000   1.625000  1400.000000  22839.000000  305000.000000
# 50%     3.500000   2.000000  1500.000000  54321.000000  400000.000000
# 75%     4.000000   2.500000  1775.000000  78912.000000  532500.000000
# max     5.000000   3.000000  2200.000000  98765.000000  780000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   beds      10 non-null     int64
#  1   baths     10 non-null     float64
#  2   size      10 non-null     int64
#  3   zip_code  10 non-null     int64
#  4   price     10 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 528.0 bytes

# %%
df['beds'].value_counts()
# Out:
# 4    4
# 3    3
# 2    2
# 5    1
# Name: beds, dtype: int64

# %%
df.head()
# Out:
#    beds  baths  size  zip_code   price
# 0     3    2.0  1800     12345  480000
# 1     4    2.5  1500     54321  420000
# 2     2    1.0  1100     98765  300000
# 3     4    2.5  1500     12345  250000
# 4     5    3.0  2200     78912  780000

# %%
df['price_per_sqft'] = df['price'] * 100000 / df['size']

# %%
df['price_per_sqft']
# Out:
# 0    2.666667e+07
# 1    2.800000e+07
# 2    2.727273e+07
# 3    1.666667e+07
# 4    3.545455e+07
# 5    3.235294e+07
# 6    2.714286e+07
# 7    2.666667e+07
# 8    1.928571e+07
# 9    3.750000e+07
# Name: price_per_sqft, dtype: float64

# %%
df.describe()
# Out:
#             beds      baths         size      zip_code          price  \
# count  10.000000  10.000000    10.000000     10.000000      10.000000
# mean    3.400000   2.050000  1580.000000  55535.200000  450000.000000
# std     0.966092   0.598609   345.768066  34044.388909  190729.593346
# min     2.000000   1.000000  1100.000000  12345.000000  250000.000000
# 25%     3.000000   1.625000  1400.000000  22839.000000  305000.000000
# 50%     3.500000   2.000000  1500.000000  54321.000000  400000.000000
# 75%     4.000000   2.500000  1775.000000  78912.000000  532500.000000
# max     5.000000   3.000000  2200.000000  98765.000000  780000.000000
#
#        price_per_sqft
# count    1.000000e+01
# mean     2.770088e+07
# std      6.438392e+06
# min      1.666667e+07
# 25%      2.666667e+07
# 50%      2.720779e+07
# 75%      3.126471e+07
# max      3.750000e+07

# %%
df.drop(columns=['size'],inplace=True)

# %%
df.drop(columns=['price_per_sqft'],inplace=True)

# %%
X=df.drop(columns=['price'])
y=df['price']

# %%
X
# Out:
#    beds  baths  zip_code
# 0     3    2.0     12345
# 1     4    2.5     54321
# 2     2    1.0     98765
# 3     4    2.5     12345
# 4     5    3.0     78912
# 5     4    2.0     12345
# 6     3    1.5     54321
# 7     2    2.0     98765
# 8     3    1.5     54321
# 9     4    2.5     78912

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (8, 6)
# (8,)

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False), ['beds']), remainder='passthrough')

# %%
scaler = StandardScaler()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lr = LinearRegression()
lr.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
pipe = make_pipeline(column_trans,scaler, lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# -126.69799720403898

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(column_trans,scaler, lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# -126.68782799410721

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler, ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)
r2_score(y_test,y_pred_ridge)
# Out:
# -88.27347068685833

# %%
print("No Regularization: ", r2_score(y_test,y_pred_lr))
print("Lasso: ", r2_score(y_test,y_pred_lasso))
print("Ridge: ", r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization:  -126.69799720403898
# Lasso:  -126.68782799410721
# Ridge:  -88.27347068685833
